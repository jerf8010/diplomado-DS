# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://cluster-dcd-jerf-m.us-central1-c.c.sharp-bulwark-351615.internal:35857">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.1.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>PySparkShell</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.option('encoding', 'UTF-8').csv('hdfs:///tmp/dcd/sirilo', inferSchema = True, header = True)

# %%
df.count()
# Out:
# 2097150

# %%
df.printSchema()
# Out:
# root
#  |-- FOLIO: string (nullable = true)
#  |-- FECHA_ALTA: string (nullable = true)
#  |-- A�O_ALTA: integer (nullable = true)
#  |-- MES_ALTA: integer (nullable = true)
#  |-- D�A_ALTA: integer (nullable = true)
#  |-- HORA_ALTA: integer (nullable = true)
#  |-- SEXO: string (nullable = true)
#  |-- EDAD: integer (nullable = true)
#  |-- ESTADO_CIVIL: string (nullable = true)
#  |-- OCUPACION: string (nullable = true)
#  |-- ESCOLARIDAD: string (nullable = true)
#  |-- ESTADO_USUARIA: string (nullable = true)
#  |-- MUNICIPIO_USUARIA: string (nullable = true)
#  |-- COLONIA_USUARIA: string (nullable = true)
#  |-- CP_USUARIA: string (nullable = true)
#  |-- ESTADO_HECHOS: string (nullable = true)
#  |-- MUNICIPIO_HECHOS: string (nullable = true)
#  |-- COLONIA_HECHOS: string (nullable = true)
#  |-- CP_HECHOS: string (nullable = true)
#  |-- ORIGEN: string (nullable = true)
#  |-- SERVICIO: string (nullable = true)
#  |-- TEMATICA_1: string (nullable = true)
# ...

# %%
df.columns
# Out:
# ['FOLIO',
#  'FECHA_ALTA',
#  'A�O_ALTA',
#  'MES_ALTA',
#  'D�A_ALTA',
#  'HORA_ALTA',
#  'SEXO',
#  'EDAD',
#  'ESTADO_CIVIL',
#  'OCUPACION',
#  'ESCOLARIDAD',
#  'ESTADO_USUARIA',
#  'MUNICIPIO_USUARIA',
#  'COLONIA_USUARIA',
#  'CP_USUARIA',
#  'ESTADO_HECHOS',
#  'MUNICIPIO_HECHOS',
#  'COLONIA_HECHOS',
#  'CP_HECHOS',
#  'ORIGEN',
#  'SERVICIO',
#  'TEMATICA_1',
#  'TEMATICA_2',
#  'TEMATICA_3',
#  'TEMATICA_4',
#  'TEMATICA_5',
#  'TEMATICA_6',
#  'TEMATICA_7']

# %%
df.describe().show()
# Out:
# 22/06/04 01:44:03 WARN org.apache.spark.sql.catalyst.util.package: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------+------------------+----------+------------------+------------------+------------------+------------------+---------+------------------+------------+--------------------+---------------+--------------+-----------------+--------------------+------------------+--------------+----------------+--------------------+------------------+----------+-----------+----------+----------------+-------------+-------------+--------------------+---------------+--------------------+
# ...

# %%
df.describe('A�O_ALTA').show()
# Out:
# [Stage 11:>                                                         (0 + 4) / 4]
# +-------+------------------+
# |summary|          A�O_ALTA|
# +-------+------------------+
# |  count|           2097150|
# |   mean|2019.0859394893068|
# | stddev|1.4513272256593328|
# |    min|              2016|
# |    max|              2022|
# +-------+------------------+

# %%
df.describe(['EDAD']).show()
# Out:
# [Stage 14:=============================>                            (2 + 2) / 4]
# +-------+-----------------+
# |summary|             EDAD|
# +-------+-----------------+
# |  count|          2097150|
# |   mean|42.83153136399399|
# | stddev|13.74357277927051|
# |    min|                1|
# |    max|               99|
# +-------+-----------------+

# %%
import pyspark.sql.functions as f

# %%
dfa = df.agg(*[f.count(f.when(f.isnull(c), c)).alias(c) for c in df.columns])
dfa.toPandas()
# Out:
#    FOLIO  FECHA_ALTA  A�O_ALTA  MES_ALTA  D�A_ALTA  HORA_ALTA  SEXO  EDAD  \
# 0      0           0         0         0         0          0     0     0
#
#    ESTADO_CIVIL  OCUPACION  ...  CP_HECHOS  ORIGEN  SERVICIO  TEMATICA_1  \
# 0             0          0  ...          0       0         0           0
#
#    TEMATICA_2  TEMATICA_3  TEMATICA_4  TEMATICA_5  TEMATICA_6  TEMATICA_7
# 0           0           0           0           0           0           0
#
# [1 rows x 28 columns]
