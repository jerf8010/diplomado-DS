# %%
from pyspark.sql.types import StructType,StructField, StringType, IntegerType, DateType 
from pyspark.sql.types import ArrayType, DoubleType, BooleanType

# %%
schema = StructType() \
  .add("trading_date_time",DateType(),True) \
  .add("network",StringType(),True) \
  .add("message_category",StringType(),True) \
  .add("message_type",IntegerType(),True) \
  .add("message_sequence",StringType(),True) \
  .add("market_exchange",StringType(),True) \
  .add("symbol",StringType(),True) \
  .add("trade_price",DoubleType(),True) \
  .add("trade_size",IntegerType(),True) \
  .add("trade_conditions",StringType(),True) \
  .add("trade_conditions2",StringType(),True)

# %%
jdbcDF = spark \
    .read \
    .option("header", False) \
    .schema(schema) \
    .csv("gs://dcd-bucket-jerf/dcd/data_trades/")


jdbcDF
# Out:
# DataFrame[trading_date_time: date, network: string, message_category: string, message_type: int, message_sequence: string, market_exchange: string, symbol: string, trade_price: double, trade_size: int, trade_conditions: string, trade_conditions2: string]

# %%
jdbcDF.printSchema()
# Out:
# root
#  |-- trading_date_time: date (nullable = true)
#  |-- network: string (nullable = true)
#  |-- message_category: string (nullable = true)
#  |-- message_type: integer (nullable = true)
#  |-- message_sequence: string (nullable = true)
#  |-- market_exchange: string (nullable = true)
#  |-- symbol: string (nullable = true)
#  |-- trade_price: double (nullable = true)
#  |-- trade_size: integer (nullable = true)
#  |-- trade_conditions: string (nullable = true)
#  |-- trade_conditions2: string (nullable = true)

# %%
jdbcDF.count()
# Out:
# 192220

# %%
jdbcDF.show()
# Out:
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# |trading_date_time|network|message_category|message_type|message_sequence|market_exchange|symbol|trade_price|trade_size|trade_conditions|trade_conditions2|
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# |       2012-08-21|      E|               I|        null|       000000268|              P|   BMI|      190.0|       100|               T|                 |
# |       2012-08-21|      E|               B|        null|       000000269|              P|   BMI|      190.0|        50|              TI|                 |
# |       2012-08-21|      E|               B|        null|       000000270|              P|   BMI|     189.92|        50|              TI|                 |
# |       2012-08-21|      E|               B|        null|       000000392|              P|   BMI|     190.67|       100|              FT|                 |
# |       2012-08-21|      E|               I|        null|       000002163|              P|   BMI|     190.43|       600|               T|                 |
# |       2012-08-21|      E|               B|        null|       000002325|              P|   BMI|     190.43|        42|              TI|                 |
# |       2012-08-21|      E|               B|        null|       000004752|              T|   BMI|     190.68|        40|             FTI|                 |
# |       2012-08-21|      E|               B|        null|       000004753|              P|   BMI|     190.67|        55|             FTI|                 |
# |       2012-08-21|      E|               B|        null|       000004754|              P|   BMI|     190.69|       105|              FT|                 |
# |       2012-08-21|      E|               B|        null|       000004830|              P|   BMI|     190.69|       300|              FT|                 |
# |       2012-08-21|      E|               I|        null|       000004871|              P|   BMI|     190.69|       100|               T|                 |
# |       2012-08-21|      E|               B|        null|       000004876|              P|   BMI|     190.69|        95|              TI|                 |
# |       2012-08-21|      E|               B|        null|       000004877|              P|   BMI|     190.75|        75|              TI|                 |
# |       2012-08-21|      E|               I|        null|       000005122|              T|   BMI|      190.9|       100|               T|                 |
# |       2012-08-21|      E|               I|        null|       000005123|              T|   BMI|     190.94|       200|               T|                 |
# |       2012-08-21|      E|               I|        null|       000005190|              T|   BMI|      190.9|       100|               @|                 |
# |       2012-08-21|      E|               I|        null|       000005191|              T|   BMI|      190.9|       100|               Q|                 |
# |       2012-08-21|      E|               B|        null|       000005192|              K|   BMI|     190.94|       100|               @|                 |
# |       2012-08-21|      E|               B|        null|       000005193|              K|   BMI|     190.94|       100|               @|                 |
# |       2012-08-21|      E|               B|        null|       000005197|              K|   BMI|     190.94|       100|               F|                 |
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# only showing top 20 rows

# %%
jdbcDF.toPandas()
# Out:
#        trading_date_time network message_category  message_type  \
# 0             2012-08-21       E                I           NaN
# 1             2012-08-21       E                B           NaN
# 2             2012-08-21       E                B           NaN
# 3             2012-08-21       E                B           NaN
# 4             2012-08-21       E                I           NaN
# ...                  ...     ...              ...           ...
# 192215        2012-08-21       E                B           NaN
# 192216        2012-08-21       E                B           NaN
# 192217        2012-08-21       E                B           NaN
# 192218        2012-08-21       E                I           NaN
# 192219        2012-08-21       E                B           NaN
#
#        message_sequence market_exchange symbol  trade_price  trade_size  \
# 0             000000268               P    BMI     190.0000         100
# 1             000000269               P    BMI     190.0000          50
# 2             000000270               P    BMI     189.9200          50
# 3             000000392               P    BMI     190.6700         100
# 4             000002163               P    BMI     190.4300         600
# ...                 ...             ...    ...          ...         ...
# 192215        001248752               D    TAC     107.9700           5
# 192216        001248845               D    TAC     108.2595      685000
# 192217        001248856               D    TAC     108.0028       76000
# 192218        001249003               P    TAC     108.0500         100
# 192219        001249606               P    TAC     108.0100         400
#
#        trade_conditions trade_conditions2
# 0                     T
# 1                    TI
# 2                    TI
# 3                    FT
# 4                     T
# ...                 ...               ...
# 192215               TI                 T
# 192216               TB                 T
# 192217               TB                 T
# 192218                T
# 192219               FT
#
# [192220 rows x 11 columns]

# %%
jdbcDF.take(5)
# Out:
# [Row(trading_date_time=datetime.date(2012, 8, 21), network='E', message_category='I', message_type=None, message_sequence='000000268', market_exchange='P', symbol='BMI', trade_price=190.0, trade_size=100, trade_conditions='T', trade_conditions2=' '),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='E', message_category='B', message_type=None, message_sequence='000000269', market_exchange='P', symbol='BMI', trade_price=190.0, trade_size=50, trade_conditions='TI', trade_conditions2=' '),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='E', message_category='B', message_type=None, message_sequence='000000270', market_exchange='P', symbol='BMI', trade_price=189.92, trade_size=50, trade_conditions='TI', trade_conditions2=' '),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='E', message_category='B', message_type=None, message_sequence='000000392', market_exchange='P', symbol='BMI', trade_price=190.67, trade_size=100, trade_conditions='FT', trade_conditions2=' '),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='E', message_category='I', message_type=None, message_sequence='000002163', market_exchange='P', symbol='BMI', trade_price=190.43, trade_size=600, trade_conditions='T', trade_conditions2=' ')]

# %%
jdbcDF.describe().toPandas().transpose()
# Out:
#                         0                   1                   2          3  \
# summary             count                mean              stddev        min
# network            192220                None                None          E
# message_category   192220                None                None          A
# message_type            0                None                None       None
# message_sequence   192220    631829.217006555   433342.7226626963  000000268
# market_exchange    192220                None                None          A
# symbol             192220                None                None       AVVB
# trade_price        192220   107.5473957413324  136.82105324874402      19.32
# trade_size         192220  221.51110186244927   7573.449432427936          1
# trade_conditions   192220                 5.0   1.044465935734187          4
# trade_conditions2   98400                None                None
#
#                           4
# summary                 max
# network                   T
# message_category          W
# message_type           None
# message_sequence   01970506
# market_exchange           Z
# symbol                 TMSF
# trade_price           585.7
# trade_size          2141076
# trade_conditions         ZI
# trade_conditions2         T

# %%
jdbcDF.describe(['trade_price']).show()
# Out:
# [Stage 13:=============================>                            (1 + 1) / 2]
# +-------+------------------+
# |summary|       trade_price|
# +-------+------------------+
# |  count|            192220|
# |   mean| 107.5473957413324|
# | stddev|136.82105324874402|
# |    min|             19.32|
# |    max|             585.7|
# +-------+------------------+

# %%
jdbcDF.orderBy(["trading_date_time", "symbol"], ascending=[1, 0]).take(10)
# Out:
# [Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000938', market_exchange='Q', symbol='TMSF', trade_price=44.97, trade_size=41, trade_conditions='@TI', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000907', market_exchange='Q', symbol='TMSF', trade_price=44.98, trade_size=66, trade_conditions='@TI', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='A', message_type=None, message_sequence='00000937', market_exchange='Q', symbol='TMSF', trade_price=44.97, trade_size=300, trade_conditions='T', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000891', market_exchange='P', symbol='TMSF', trade_price=44.93, trade_size=34, trade_conditions='@FTI', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='A', message_type=None, message_sequence='00000899', market_exchange='D', symbol='TMSF', trade_price=45.12, trade_size=200, trade_conditions='T', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000908', market_exchange='Q', symbol='TMSF', trade_price=44.99, trade_size=34, trade_conditions='@TI', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000909', market_exchange='Q', symbol='TMSF', trade_price=44.99, trade_size=25, trade_conditions='@FTI', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000890', market_exchange='P', symbol='TMSF', trade_price=44.94, trade_size=66, trade_conditions='@FTI', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000999', market_exchange='Q', symbol='TMSF', trade_price=44.98, trade_size=200, trade_conditions='@FT', trade_conditions2=None),
#  Row(trading_date_time=datetime.date(2012, 8, 21), network='T', message_category='W', message_type=None, message_sequence='00000952', market_exchange='Q', symbol='TMSF', trade_price=44.99, trade_size=200, trade_conditions='@FT', trade_conditions2=None)]

# %%
jdbcDF.groupBy("trading_date_time", "symbol").count().sort("trading_date_time", "symbol", ascending=[1, 0]).show()
# Out:
# [Stage 22:=============================>                            (1 + 1) / 2]
# +-----------------+------+-----+
# |trading_date_time|symbol|count|
# +-----------------+------+-----+
# |       2012-08-21|  TMSF|80734|
# |       2012-08-21|   TAC|21790|
# |       2012-08-21|   RAD| 3816|
# |       2012-08-21|  MOOT|13086|
# |       2012-08-21|  HMAT| 7868|
# |       2012-08-21|  GRIN| 2794|
# |       2012-08-21|   BMI|21871|
# |       2012-08-21|  AVVB|40261|
# +-----------------+------+-----+

# %%
from pyspark.sql.functions import when
df2 = jdbcDF.select("symbol","trade_price","trade_size","market_exchange" \
      ,when(jdbcDF.market_exchange == "K","KALL") \
      .when(jdbcDF.market_exchange == "P","PAll") \
      .when(jdbcDF.market_exchange.isNull() ,"NO ESPECIFICADO") \
      .otherwise(jdbcDF.market_exchange).alias("market"))
df2.show()
# Out:
# +------+-----------+----------+---------------+------+
# |symbol|trade_price|trade_size|market_exchange|market|
# +------+-----------+----------+---------------+------+
# |   BMI|      190.0|       100|              P|  PAll|
# |   BMI|      190.0|        50|              P|  PAll|
# |   BMI|     189.92|        50|              P|  PAll|
# |   BMI|     190.67|       100|              P|  PAll|
# |   BMI|     190.43|       600|              P|  PAll|
# |   BMI|     190.43|        42|              P|  PAll|
# |   BMI|     190.68|        40|              T|     T|
# |   BMI|     190.67|        55|              P|  PAll|
# |   BMI|     190.69|       105|              P|  PAll|
# |   BMI|     190.69|       300|              P|  PAll|
# |   BMI|     190.69|       100|              P|  PAll|
# |   BMI|     190.69|        95|              P|  PAll|
# |   BMI|     190.75|        75|              P|  PAll|
# |   BMI|      190.9|       100|              T|     T|
# |   BMI|     190.94|       200|              T|     T|
# |   BMI|      190.9|       100|              T|     T|
# |   BMI|      190.9|       100|              T|     T|
# |   BMI|     190.94|       100|              K|  KALL|
# |   BMI|     190.94|       100|              K|  KALL|
# |   BMI|     190.94|       100|              K|  KALL|
# +------+-----------+----------+---------------+------+
# only showing top 20 rows

# %%
jdbcDF.selectExpr("*","trade_size * 10 AS trade_size10", "abs(trade_size) AS trade_size_abs").show()
# Out:
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+------------+--------------+
# |trading_date_time|network|message_category|message_type|message_sequence|market_exchange|symbol|trade_price|trade_size|trade_conditions|trade_conditions2|trade_size10|trade_size_abs|
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+------------+--------------+
# |       2012-08-21|      E|               I|        null|       000000268|              P|   BMI|      190.0|       100|               T|                 |        1000|           100|
# |       2012-08-21|      E|               B|        null|       000000269|              P|   BMI|      190.0|        50|              TI|                 |         500|            50|
# |       2012-08-21|      E|               B|        null|       000000270|              P|   BMI|     189.92|        50|              TI|                 |         500|            50|
# |       2012-08-21|      E|               B|        null|       000000392|              P|   BMI|     190.67|       100|              FT|                 |        1000|           100|
# |       2012-08-21|      E|               I|        null|       000002163|              P|   BMI|     190.43|       600|               T|                 |        6000|           600|
# |       2012-08-21|      E|               B|        null|       000002325|              P|   BMI|     190.43|        42|              TI|                 |         420|            42|
# |       2012-08-21|      E|               B|        null|       000004752|              T|   BMI|     190.68|        40|             FTI|                 |         400|            40|
# |       2012-08-21|      E|               B|        null|       000004753|              P|   BMI|     190.67|        55|             FTI|                 |         550|            55|
# |       2012-08-21|      E|               B|        null|       000004754|              P|   BMI|     190.69|       105|              FT|                 |        1050|           105|
# |       2012-08-21|      E|               B|        null|       000004830|              P|   BMI|     190.69|       300|              FT|                 |        3000|           300|
# |       2012-08-21|      E|               I|        null|       000004871|              P|   BMI|     190.69|       100|               T|                 |        1000|           100|
# |       2012-08-21|      E|               B|        null|       000004876|              P|   BMI|     190.69|        95|              TI|                 |         950|            95|
# |       2012-08-21|      E|               B|        null|       000004877|              P|   BMI|     190.75|        75|              TI|                 |         750|            75|
# |       2012-08-21|      E|               I|        null|       000005122|              T|   BMI|      190.9|       100|               T|                 |        1000|           100|
# |       2012-08-21|      E|               I|        null|       000005123|              T|   BMI|     190.94|       200|               T|                 |        2000|           200|
# |       2012-08-21|      E|               I|        null|       000005190|              T|   BMI|      190.9|       100|               @|                 |        1000|           100|
# |       2012-08-21|      E|               I|        null|       000005191|              T|   BMI|      190.9|       100|               Q|                 |        1000|           100|
# |       2012-08-21|      E|               B|        null|       000005192|              K|   BMI|     190.94|       100|               @|                 |        1000|           100|
# |       2012-08-21|      E|               B|        null|       000005193|              K|   BMI|     190.94|       100|               @|                 |        1000|           100|
# |       2012-08-21|      E|               B|        null|       000005197|              K|   BMI|     190.94|       100|               F|                 |        1000|           100|
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+------------+--------------+
# only showing top 20 rows

# %%
jdbcDF.where(jdbcDF.market_exchange == "T").show()
# Out:
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# |trading_date_time|network|message_category|message_type|message_sequence|market_exchange|symbol|trade_price|trade_size|trade_conditions|trade_conditions2|
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# |       2012-08-21|      E|               B|        null|       000004752|              T|   BMI|     190.68|        40|             FTI|                 |
# |       2012-08-21|      E|               I|        null|       000005122|              T|   BMI|      190.9|       100|               T|                 |
# |       2012-08-21|      E|               I|        null|       000005123|              T|   BMI|     190.94|       200|               T|                 |
# |       2012-08-21|      E|               I|        null|       000005190|              T|   BMI|      190.9|       100|               @|                 |
# |       2012-08-21|      E|               I|        null|       000005191|              T|   BMI|      190.9|       100|               Q|                 |
# |       2012-08-21|      E|               I|        null|       000005255|              T|   BMI|     190.94|       200|               @|                 |
# |       2012-08-21|      E|               I|        null|       000005310|              T|   BMI|     190.91|       100|               @|                 |
# |       2012-08-21|      E|               B|        null|       000006315|              T|   BMI|     190.79|       100|               F|                 |
# |       2012-08-21|      E|               B|        null|       000006317|              T|   BMI|     190.68|       100|               F|                 |
# |       2012-08-21|      E|               B|        null|       000006318|              T|   BMI|     190.68|       100|               F|                 |
# |       2012-08-21|      E|               I|        null|       000006853|              T|   BMI|     190.79|        52|               I|                 |
# |       2012-08-21|      E|               I|        null|       000006855|              T|   BMI|     190.82|        48|               I|                 |
# |       2012-08-21|      E|               I|        null|       000006863|              T|   BMI|     190.82|        52|               I|                 |
# |       2012-08-21|      E|               B|        null|       000007271|              T|   BMI|     190.78|         1|              FI|                 |
# |       2012-08-21|      E|               B|        null|       000007315|              T|   BMI|     190.67|         3|              FI|                 |
# |       2012-08-21|      E|               B|        null|       000007316|              T|   BMI|     190.67|         2|              FI|                 |
# |       2012-08-21|      E|               B|        null|       000007317|              T|   BMI|     190.65|        95|              FI|                 |
# |       2012-08-21|      E|               I|        null|       000007639|              T|   BMI|     190.63|        15|               I|                 |
# |       2012-08-21|      E|               I|        null|       000008634|              T|   BMI|     190.82|       100|               @|                 |
# |       2012-08-21|      E|               I|        null|       000008920|              T|   BMI|     190.82|       100|               @|                 |
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# only showing top 20 rows

# %%
jdbcDF.where("market_exchange == 'T' AND trade_price = 190.9").show()
# Out:
# [Stage 29:>                                                         (0 + 1) / 1]
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# |trading_date_time|network|message_category|message_type|message_sequence|market_exchange|symbol|trade_price|trade_size|trade_conditions|trade_conditions2|
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+
# |       2012-08-21|      E|               I|        null|       000005122|              T|   BMI|      190.9|       100|               T|                 |
# |       2012-08-21|      E|               I|        null|       000005190|              T|   BMI|      190.9|       100|               @|                 |
# |       2012-08-21|      E|               I|        null|       000005191|              T|   BMI|      190.9|       100|               Q|                 |
# |       2012-08-21|      E|               I|        null|       000038357|              T|   BMI|      190.9|       400|               @|                 |
# |       2012-08-21|      E|               I|        null|       000038358|              T|   BMI|      190.9|       100|               @|                 |
# |       2012-08-21|      E|               I|        null|       000038359|              T|   BMI|      190.9|       100|               @|                 |
# +-----------------+-------+----------------+------------+----------------+---------------+------+-----------+----------+----------------+-----------------+

# %%
jdbcDF.select("network", "message_category", "message_sequence")\
    .where((jdbcDF.market_exchange == "T") & (jdbcDF.trade_price == 190.9)) \
    .sort("message_sequence").show()
# Out:
# +-------+----------------+----------------+
# |network|message_category|message_sequence|
# +-------+----------------+----------------+
# |      E|               I|       000005122|
# |      E|               I|       000005190|
# |      E|               I|       000005191|
# |      E|               I|       000038357|
# |      E|               I|       000038358|
# |      E|               I|       000038359|
# +-------+----------------+----------------+

# %%
from pyspark.sql.functions import countDistinct

jdbcDF.select("market_exchange", "symbol") \
  .groupBy("market_exchange")\
  .agg(countDistinct("symbol").alias("distinct_symbol")) \
  .show()
# Out:
# +---------------+---------------+
# |market_exchange|distinct_symbol|
# +---------------+---------------+
# |              K|              8|
# |              Q|              2|
# |              T|              6|
# |              B|              8|
# |              Y|              8|
# |              M|              5|
# |              D|              8|
# |              J|              8|
# |              Z|              8|
# |              N|              6|
# |              X|              8|
# |              A|              1|
# |              P|              8|
# +---------------+---------------+

# %%
print(jdbcDF.where((jdbcDF.market_exchange == "K")).count())
# Out:
# 13032

# %%
jdbcDF.select("market_exchange", "symbol") \
    .where((jdbcDF.market_exchange == "K")) \
    .groupBy("market_exchange", "symbol").count().show()
# Out:
# +---------------+------+-----+
# |market_exchange|symbol|count|
# +---------------+------+-----+
# |              K|  AVVB| 1874|
# |              K|  MOOT|  852|
# |              K|  HMAT| 1209|
# |              K|  TMSF| 6001|
# |              K|   RAD|  144|
# |              K|   BMI| 1599|
# |              K|   TAC| 1162|
# |              K|  GRIN|  191|
# +---------------+------+-----+

# %%
jdbcDF.select("market_exchange", "trade_price") \
    .where((jdbcDF.market_exchange == "K") & (jdbcDF.symbol == "GRIN")) \
    .groupBy("market_exchange", "trade_price").sum().show()
# Out:
# +---------------+-----------+------------------+
# |market_exchange|trade_price|  sum(trade_price)|
# +---------------+-----------+------------------+
# |              K|      78.95|             78.95|
# |              K|      78.69|            236.07|
# |              K|      78.61|             78.61|
# |              K|      78.92|            236.76|
# |              K|      78.41|            313.64|
# |              K|      78.71|            157.42|
# |              K|      79.01|            158.02|
# |              K|      78.66|393.29999999999995|
# |              K|      79.25|             158.5|
# |              K|      78.36|             78.36|
# |              K|      78.62|             78.62|
# |              K|      78.79|            157.58|
# |              K|      79.02|            158.04|
# |              K|      78.45|             470.7|
# |              K|      78.57|235.70999999999998|
# |              K|      78.39|             78.39|
# |              K|      78.48|392.40000000000003|
# |              K|      79.18|             79.18|
# |              K|      78.84|            315.36|
# |              K|      78.67|             78.67|
# +---------------+-----------+------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col,sum,avg,max

jdbcDF.groupBy("market_exchange","symbol") \
    .agg(sum("trade_price").alias("sum_trade_price"), \
         avg("trade_price").alias("avg_trade_price"), \
         sum("trade_size").alias("sum_trade_size"), \
         max("trade_size").alias("max_trade_size") \
     ) \
    .filter(col("sum_trade_price") > 100000)  \
    .sort("sum_trade_price") \
    .show(truncate=False)
# Out:
# +---------------+------+------------------+------------------+--------------+--------------+
# |market_exchange|symbol|sum_trade_price   |avg_trade_price   |sum_trade_size|max_trade_size|
# +---------------+------+------------------+------------------+--------------+--------------+
# |K              |AVVB  |103014.31499999992|54.97028548559227 |322326        |25000         |
# |Y              |AVVB  |103048.57500000022|54.98856723585924 |197345        |1200          |
# |B              |BMI   |106718.15500000019|191.59453321364487|45741         |1700          |
# |D              |HMAT  |121312.86489999999|44.404416142020494|610860        |5000          |
# |K              |TAC   |125733.66500000004|108.20453098106715|145573        |3937          |
# |B              |TMSF  |148723.12000000113|45.136000000000344|491084        |2800          |
# |J              |TMSF  |170228.53000000224|45.12951484623601 |517004        |2247          |
# |Y              |BMI   |180093.16100000014|191.58846914893633|68914         |1029          |
# |J              |MOOT  |185316.81999999977|582.7572955974836 |22742         |200           |
# |N              |AVVB  |216887.00500000143|54.9637620375067  |1423810       |259831        |
# |Z              |TAC   |220354.75500000006|108.17611929307809|183971        |1300          |
# |P              |TAC   |224797.9549999994 |108.17995909528364|218169        |3593          |
# |Z              |BMI   |227608.83500000028|191.58992845117868|92604         |1000          |
# |B              |MOOT  |237132.81999999995|582.6359213759213 |20963         |170           |
# |Y              |MOOT  |237134.61499999993|582.6403316953315 |25069         |300           |
# |P              |AVVB  |245031.75500000134|54.96450314042202 |632921        |2100          |
# |Z              |AVVB  |265732.96999999904|54.98302710531741 |634915        |2900          |
# |K              |TMSF  |270765.33000000886|45.12003499416912 |1116097       |16600         |
# |Y              |TMSF  |280222.0670000037 |45.138863885309874|760279        |4800          |
# |K              |BMI   |306466.5550000001 |191.66138524077556|180919        |2000          |
# +---------------+------+------------------+------------------+--------------+--------------+
# only showing top 20 rows

# %%
jdbcDF.write.partitionBy("symbol").saveAsTable("trade_hive")
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# 22/06/04 15:14:30 WARN org.apache.hadoop.hive.ql.session.SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.
