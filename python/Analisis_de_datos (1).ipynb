# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Muertes Maternas 2019_20112020.csv', encoding = 'latin-1')

# %%
df.head(5)
# Out:
#    ANIO_NACIMIENTO  MES_NACIMIENTO  MES_NACIMIENTOD  DIA_NACIMIENTO  EDAD  \
# 0                0               0  NO ESPECIFICADO               0    35
# 1                0               0  NO ESPECIFICADO               0    20
# 2             1962               7            JULIO              12    39
# 3             1974               2          FEBRERO              10    27
# 4             1980               4            ABRIL              18    20
#
#    ESTADO_CONYUGAL ESTADO_CONYUGALD  ENTIDAD_RESIDENCIA ENTIDAD_RESIDENCIAD  \
# 0                4      UNION LIBRE                   8           CHIHUAHUA
# 1                5           CASADO                   8           CHIHUAHUA
# 2                5           CASADO                  12            GUERRERO
# 3                5           CASADO                  12            GUERRERO
# 4                4      UNION LIBRE                  18             NAYARIT
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19932 entries, 0 to 19931
# Data columns (total 58 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   ANIO_NACIMIENTO            19932 non-null  int64
#  1   MES_NACIMIENTO             19932 non-null  int64
#  2   MES_NACIMIENTOD            19932 non-null  object
#  3   DIA_NACIMIENTO             19932 non-null  int64
#  4   EDAD                       19932 non-null  int64
#  5   ESTADO_CONYUGAL            19932 non-null  int64
#  6   ESTADO_CONYUGALD           19932 non-null  object
#  7   ENTIDAD_RESIDENCIA         19932 non-null  int64
#  8   ENTIDAD_RESIDENCIAD        19932 non-null  object
#  9   MUNICIPIO_RESIDENCIA       19932 non-null  int64
#  10  MUNICIPIO_RESIDENCIAD      19932 non-null  object
#  11  LOCALIDAD_RESIDENCIA       19932 non-null  int64
#  12  LOCALIDAD_RESIDENCIAD      19932 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['ANIO_NACIMIENTO', 'MES_NACIMIENTO', 'MES_NACIMIENTOD',
#        'DIA_NACIMIENTO', 'EDAD', 'ESTADO_CONYUGAL', 'ESTADO_CONYUGALD',
#        'ENTIDAD_RESIDENCIA', 'ENTIDAD_RESIDENCIAD', 'MUNICIPIO_RESIDENCIA',
#        'MUNICIPIO_RESIDENCIAD', 'LOCALIDAD_RESIDENCIA',
#        'LOCALIDAD_RESIDENCIAD', 'TAMANIO_LOCALIDAD', 'TAMANIO_LOCALIDADD',
#        'OCUPACION_HABITUAL', 'OCUPACION_HABITUALD', 'ESCOLARIDAD',
#        'ESCOLARIDADD', 'DERECHOHABIENCIA', 'DERECHOHABIENCIAD',
#        'ENTIDAD_OCURRENCIA', 'ENTIDAD_OCURRENCIAD', 'MUNICIPIO_OCURRENCIA',
#        'MUNICIPIO_OCURRENCIAD', 'LOCALIDAD_OCURRENCIA',
#        'LOCALIDAD_OCURRENCIAD', 'SITIO_DEFUNCION', 'SITIO_DEFUNCIOND',
#        'ANIO_DEFUNCION', 'MES_DEFUNCION', 'MES_DEFUNCIOND', 'DIA_DEFUNCION',
#        'HORA_DEFUNCION', 'MINUTOS_DEFUNCION', 'ASISTENCIA_MEDICA',
#        'ASISTENCIA_MEDICAD', 'CAUSA_CIE_4', 'CAUSA_CIE_4D', 'CERTIFICO',
#        'CERTIFICOD', 'ENTIDAD_REGISTRO', 'ENTIDAD_REGISTROD',
# ...

# %%
df['ENTIDAD_RESIDENCIAD']
# Out:
# 0         CHIHUAHUA
# 1         CHIHUAHUA
# 2          GUERRERO
# 3          GUERRERO
# 4           NAYARIT
#             ...
# 19927    TAMAULIPAS
# 19928    TAMAULIPAS
# 19929    TAMAULIPAS
# 19930    TAMAULIPAS
# 19931    TAMAULIPAS
# Name: ENTIDAD_RESIDENCIAD, Length: 19932, dtype: object

# %%
df.loc[0]
# Out:
# ANIO_NACIMIENTO                                                              0
# MES_NACIMIENTO                                                               0
# MES_NACIMIENTOD                                                NO ESPECIFICADO
# DIA_NACIMIENTO                                                               0
# EDAD                                                                        35
# ESTADO_CONYUGAL                                                              4
# ESTADO_CONYUGALD                                                   UNION LIBRE
# ENTIDAD_RESIDENCIA                                                           8
# ENTIDAD_RESIDENCIAD                                                  CHIHUAHUA
# MUNICIPIO_RESIDENCIA                                                        29
# MUNICIPIO_RESIDENCIAD                                        GUADALUPE Y CALVO
# LOCALIDAD_RESIDENCIA                                                       752
# ...

# %%
df[ df['EDAD'] > 80 ]
# Out:
#        ANIO_NACIMIENTO  MES_NACIMIENTO  MES_NACIMIENTOD  DIA_NACIMIENTO  EDAD  \
# 426                  0               0  NO ESPECIFICADO               0   998
# 478                  0               0  NO ESPECIFICADO               0   998
# 537                  0               0  NO ESPECIFICADO               0   998
# 580                  0               0  NO ESPECIFICADO               0   998
# 880                  0               0  NO ESPECIFICADO               0   998
# 992                  0               0  NO ESPECIFICADO               0   998
# 997                  0               0  NO ESPECIFICADO               0   998
# 1056                 0               0  NO ESPECIFICADO               0   998
# 1167                 0               0  NO ESPECIFICADO               0   998
# 1199                 0               0  NO ESPECIFICADO               0   998
# 1369                 0               0  NO ESPECIFICADO               0   998
# ...

# %%
df['EDAD'].describe()
# Out:
# count    19932.000000
# mean        29.694311
# std         35.122756
# min         11.000000
# 25%         22.000000
# 50%         28.000000
# 75%         34.000000
# max        998.000000
# Name: EDAD, dtype: float64

# %%
mean_edad = df[ df['EDAD'] != 998 ]['EDAD'].mean()

# %%
pd.to_numeric(df['EDAD'])
# Out:
# 0        35
# 1        20
# 2        39
# 3        27
# 4        20
#          ..
# 19927    33
# 19928    17
# 19929    14
# 19930    27
# 19931    36
# Name: EDAD, Length: 19932, dtype: int64

# %%
df['EDAD'] = df['EDAD'].apply(lambda x: mean_edad  if x > 150 else x)
df['EDAD'].describe()
# Out:
# count    19932.000000
# mean        28.478274
# std          7.486899
# min         11.000000
# 25%         22.000000
# 50%         28.000000
# 75%         34.000000
# max         86.000000
# Name: EDAD, dtype: float64

# %%
df['LUGAR_NACIMIENTO'] = df['LOCALIDAD_RESIDENCIAD'] + ', ' + df['ENTIDAD_RESIDENCIAD']

# %%
df.head(5)
# Out:
#    ANIO_NACIMIENTO  MES_NACIMIENTO  MES_NACIMIENTOD  DIA_NACIMIENTO  EDAD  \
# 0                0               0  NO ESPECIFICADO               0  35.0
# 1                0               0  NO ESPECIFICADO               0  20.0
# 2             1962               7            JULIO              12  39.0
# 3             1974               2          FEBRERO              10  27.0
# 4             1980               4            ABRIL              18  20.0
#
#    ESTADO_CONYUGAL ESTADO_CONYUGALD  ENTIDAD_RESIDENCIA ENTIDAD_RESIDENCIAD  \
# 0                4      UNION LIBRE                   8           CHIHUAHUA
# 1                5           CASADO                   8           CHIHUAHUA
# 2                5           CASADO                  12            GUERRERO
# 3                5           CASADO                  12            GUERRERO
# 4                4      UNION LIBRE                  18             NAYARIT
#
# ...

# %%
df.duplicated().value_counts()
# Out:
# False    19932
# dtype: int64

# %%
df.isna().value_counts()
# Out:
# ANIO_NACIMIENTO  MES_NACIMIENTO  MES_NACIMIENTOD  DIA_NACIMIENTO  EDAD   ESTADO_CONYUGAL  ESTADO_CONYUGALD  ENTIDAD_RESIDENCIA  ENTIDAD_RESIDENCIAD  MUNICIPIO_RESIDENCIA  MUNICIPIO_RESIDENCIAD  LOCALIDAD_RESIDENCIA  LOCALIDAD_RESIDENCIAD  TAMANIO_LOCALIDAD  TAMANIO_LOCALIDADD  OCUPACION_HABITUAL  OCUPACION_HABITUALD  ESCOLARIDAD  ESCOLARIDADD  DERECHOHABIENCIA  DERECHOHABIENCIAD  ENTIDAD_OCURRENCIA  ENTIDAD_OCURRENCIAD  MUNICIPIO_OCURRENCIA  MUNICIPIO_OCURRENCIAD  LOCALIDAD_OCURRENCIA  LOCALIDAD_OCURRENCIAD  SITIO_DEFUNCION  SITIO_DEFUNCIOND  ANIO_DEFUNCION  MES_DEFUNCION  MES_DEFUNCIOND  DIA_DEFUNCION  HORA_DEFUNCION  MINUTOS_DEFUNCION  ASISTENCIA_MEDICA  ASISTENCIA_MEDICAD  CAUSA_CIE_4  CAUSA_CIE_4D  CERTIFICO  CERTIFICOD  ENTIDAD_REGISTRO  ENTIDAD_REGISTROD  MUNICIPIO_REGISTRO  MUNICIPIO_REGISTROD  ANIO_REGISTRO  MES_REGISTRO  MES_REGISTROD  DIA_REGISTRO  ANIO_CERTIFICACION  MES_CERTIFICACION  MES_CERTIFICACIOND  DIA_CERTIFICACION  ANIO_BASE_DATOS  RAZON_MORTALIDAD_MATERNA  RAZON_
# ...
