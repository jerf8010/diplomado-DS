# %%
import pandas as pd

# %%
cities_df = pd.read_csv('/content/Cities.csv')

# %%
cities_df.head(5)
# Out:
#        city         country  latitude  longitude  temperature
# 0   Aalborg         Denmark     57.03       9.92         7.52
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2    Abisko          Sweden     63.35      18.83         0.20
# 3     Adana          Turkey     36.99      35.32        18.67
# 4  Albacete           Spain     39.00      -1.87        12.62

# %%
# %matplotlib inline

# %%
cities_df.groupby('country')['temperature'].mean().hist()

# %%
cities_df.groupby('country')

# %%
[x for x in cities_df.groupby('country')][1]
# Out:
# ('Andorra',       city  country  latitude  longitude  temperature
#  9  Andorra  Andorra      42.5       1.52          9.6)

# %%
[x for x in cities_df.groupby('country')][1][0]
# Out:
# 'Andorra'

# %%
[x for x in cities_df.groupby('country')][1][1]
# Out:
#       city  country  latitude  longitude  temperature
# 9  Andorra  Andorra      42.5       1.52          9.6

# %%
for country_name, country_df in cities_df.groupby('country'):
  print(country_name)
# Out:
# Albania
# Andorra
# Austria
# Belarus
# Belgium
# Bosnia and Herzegovina
# Bulgaria
# Croatia
# Czech Republic
# Denmark
# Estonia
# Finland
# France
# Germany
# Greece
# Hungary
# Ireland
# Italy
# Latvia
# Lithuania
# Macedonia
# Moldova
# Montenegro
# Netherlands
# Norway
# Poland
# Portugal
# Romania
# Serbia
# Slovakia
# Slovenia
# Spain
# Sweden
# Switzerland
# Turkey
# Ukraine
# United Kingdom

# %%
for country_name, country_df in cities_df.groupby('country'):
  print(country_df)
# Out:
#        city  country  latitude  longitude  temperature
# 78  Elbasan  Albania     41.12      20.08        15.18
#       city  country  latitude  longitude  temperature
# 9  Andorra  Andorra      42.5       1.52          9.6
#           city  country  latitude  longitude  temperature
# 95        Graz  Austria     47.08      15.41         6.91
# 105  Innsbruck  Austria     47.28      11.41         4.54
# 125       Linz  Austria     48.32      14.29         6.79
# 175   Salzburg  Austria     47.81      13.04         4.62
# 203     Vienna  Austria     48.20      16.37         7.86
#        city  country  latitude  longitude  temperature
# 47    Brest  Belarus     52.10      23.70         6.73
# 102  Hrodna  Belarus     53.68      23.83         6.07
# 138   Mazyr  Belarus     52.05      29.27         6.25
# 142   Minsk  Belarus     53.90      27.57         5.28
# 151   Orsha  Belarus     54.52      30.42         4.93
# 161   Pinsk  Belarus     52.13      26.09         6.42
# ...

# %%
import math
import numpy as np

# %%
cities_df.groupby('country').apply(lambda x: x['temperature'] + 1)
# Out:
# country
# Albania         78     16.18
# Andorra         9      10.60
# Austria         95      7.91
#                 105     5.54
#                 125     7.79
#                        ...
# United Kingdom  76      8.43
#                 84     11.14
#                 92      9.60
#                 106     9.00
#                 188    10.73
# Name: temperature, Length: 213, dtype: float64

# %%
cities_df['city'].head(1)
# Out:
# 0    Aalborg
# Name: city, dtype: object

# %%
cities_df[1:5]
# Out:
#        city         country  latitude  longitude  temperature
# 1  Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2    Abisko          Sweden     63.35      18.83         0.20
# 3     Adana          Turkey     36.99      35.32        18.67
# 4  Albacete           Spain     39.00      -1.87        12.62

# %%
cities_df.loc[[1, 5, 1]]
# Out:
#         city         country  latitude  longitude  temperature
# 1   Aberdeen  United Kingdom     57.17      -2.08         8.10
# 5  Algeciras           Spain     36.13      -5.47        17.38
# 1   Aberdeen  United Kingdom     57.17      -2.08         8.10

# %%
cities_df.iloc[0]
# Out:
# city           Aalborg
# country        Denmark
# latitude         57.03
# longitude         9.92
# temperature       7.52
# Name: 0, dtype: object

# %%
cities_df.iat[0, 2]
# Out:
# 57.03

# %%
cities_df.at[0, 'temperature']
# Out:
# 7.52

# %%
# %%timeit
cities_df.loc[0]
# Out:
# 1000 loops, best of 5: 245 µs per loop

# %%
# %%timeit
cities_df.at[0, 'temperature']
# Out:
# The slowest run took 19.07 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 5: 4.61 µs per loop

# %%
cities_df[cities_df['temperature'] > 10 & cities_df['country'].apply(lambda x: x[0].lower() == 'a')]
# Out:
#             city         country  latitude  longitude  temperature
# 0        Aalborg         Denmark     57.03       9.92         7.52
# 1       Aberdeen  United Kingdom     57.17      -2.08         8.10
# 2         Abisko          Sweden     63.35      18.83         0.20
# 3          Adana          Turkey     36.99      35.32        18.67
# 4       Albacete           Spain     39.00      -1.87        12.62
# ..           ...             ...       ...        ...          ...
# 208  Yevpatoriya         Ukraine     45.20      33.36        10.02
# 209     Zaragoza           Spain     41.65      -0.89        14.17
# 210     Zhytomyr         Ukraine     50.25      28.66         6.67
# 211    Zonguldak          Turkey     41.43      31.78        10.64
# 212       Zurich     Switzerland     47.38       8.56         6.68
#
# [212 rows x 5 columns]

# %%
cities_df['yo'] = None

# %%
cities_df
# Out:
#             city         country  latitude  longitude  temperature    yo
# 0        Aalborg         Denmark     57.03       9.92         7.52  None
# 1       Aberdeen  United Kingdom     57.17      -2.08         8.10  None
# 2         Abisko          Sweden     63.35      18.83         0.20  None
# 3          Adana          Turkey     36.99      35.32        18.67  None
# 4       Albacete           Spain     39.00      -1.87        12.62  None
# ..           ...             ...       ...        ...          ...   ...
# 208  Yevpatoriya         Ukraine     45.20      33.36        10.02  None
# 209     Zaragoza           Spain     41.65      -0.89        14.17  None
# 210     Zhytomyr         Ukraine     50.25      28.66         6.67  None
# 211    Zonguldak          Turkey     41.43      31.78        10.64  None
# 212       Zurich     Switzerland     47.38       8.56         6.68  None
#
# [213 rows x 6 columns]

# %%
cities_df.fillna(0, inplace = True)

# %%
cities_df
# Out:
#             city         country  latitude  longitude  temperature  yo
# 0        Aalborg         Denmark     57.03       9.92         7.52   0
# 1       Aberdeen  United Kingdom     57.17      -2.08         8.10   0
# 2         Abisko          Sweden     63.35      18.83         0.20   0
# 3          Adana          Turkey     36.99      35.32        18.67   0
# 4       Albacete           Spain     39.00      -1.87        12.62   0
# ..           ...             ...       ...        ...          ...  ..
# 208  Yevpatoriya         Ukraine     45.20      33.36        10.02   0
# 209     Zaragoza           Spain     41.65      -0.89        14.17   0
# 210     Zhytomyr         Ukraine     50.25      28.66         6.67   0
# 211    Zonguldak          Turkey     41.43      31.78        10.64   0
# 212       Zurich     Switzerland     47.38       8.56         6.68   0
#
# [213 rows x 6 columns]
